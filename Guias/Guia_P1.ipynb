# %% [markdown]
# 1) Dada la siguiente señal analógica:
# $$x(t) = 3\cos(2\pi \cdot 100 t) + 2\sin(2\pi \cdot 250 t) - \cos(2\pi \cdot 400 t)$$
#
# a) ¿Cuál es la frecuencia de Nyquist de la señal analógica combinada?
#
# b) ¿Cuál es la frecuencia de muestreo mínima $f_s$ teórica necesaria para digitalizar la señal sin perder información?

# %% [markdown]
# 2) Explicar conceptualmente qué es el fenómeno de *aliasing* (solapamiento) y en qué condiciones ocurre.
