# %% [markdown]
# 1$)$ Dada la señal analógica $x(t) = 3\cos(2\pi 100 t) + 2\sin(2\pi 250 t) - \cos(2\pi 400 t)$
#
# a) ¿Cuál es la frecuencia de Nyquist de la señal?
# b) ¿Cuál es la frecuencia de muestreo mínima $f_s$ teórica para no perder información?
