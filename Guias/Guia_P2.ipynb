# %% [markdown]
# 1) Dado un sistema LTI cuya respuesta al impulso es $h[n] = (0.8)^n u[n]$, determinar analíticamente la salida $y[n]$ para una entrada escalón unitario $x[n] = u[n]$.

# %% [markdown]
# 2) Dadas las señales $x[n]$ y $h[n]$ de la figura 2.1, realizar la convolución $y[n] = x[n] * h[n]$ y graficar paso a paso la salida resultante.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
x = [0, 1, 2, 3]
y = [1, 2, 1, 0]
a = [0, 1, 2, 3]
b = [1, 1, 1, 0]
plt.title("Fig 2.1")
plt.subplot(1,2,1)
plt.stem(x, y)
plt.xlabel("n")
plt.grid()
plt.subplot(1,2,2)
plt.stem(a, b)
plt.xlabel("n")
plt.grid()
plt.show()

# %% [markdown]
# 3) Considere dos sistemas LTI. El **Sistema B** está definido por la ecuación de diferencias $y[n] = x[n] + x[n-2]$. El **Sistema A** corresponde al sistema analizado en el ejercicio anterior, con su respectiva respuesta al impulso $h_A[n]$.
#
# a) Hallar la respuesta al impulso $h_B[n]$ para el Sistema B.
#
# b) Comparar $h_B[n]$ con $h_A[n]$. ¿Son iguales? En caso de que no lo sean, ¿qué términos debería agregar o modificar en la ecuación de diferencias del Sistema B para que su respuesta al impulso sea idéntica a la del Sistema A?
#
# c) **Evaluación con señal de prueba:**
#    Supongamos que la entrada al Sistema B ($y[n] = x[n] + x[n-2]$) es un pulso rectangular de amplitud unitaria y duración 3:
#    $$x[n] = \{1, 1, 1\} \quad \text{para } n=0, 1, 2$$
#
# I. Calcular analíticamente la salida $y[n]$.
#
# II. Graficar $x[n]$ e $y[n]$.
#
# III. ¿Cómo afectó el sistema a la "duración" de la señal original?

# %% [markdown]
# 4) Dada la señal de duración finita $x[n] = \{1, 2, 1\}$ (válida para $n = -1, 0, 1$):
#
# a) Calcular la secuencia de autocorrelación discreta $r_{xx}[\ell]$.
#
# b) Graficar el resultado. ¿En qué valor de retardo $\ell$ se da el máximo de $r_{xx}[\ell]$ y qué significado físico tiene ese valor respecto a la energía de la señal original $x[n]$?
