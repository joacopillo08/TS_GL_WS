# %% [markdown]
# 1$)$ Determinar si los siguientes sistemas son: (i) Lineales, (ii) Invariantes en el tiempo, (iii) Causales y (iv) Estables.
#
# a) $y[n] = x[n] \cdot \cos(0.5 \pi n)$
#
# b) $y[n] = x^2[n]$
#
# c) $y[n] = x[n+1] + x[n]$

# %% [markdown]
# 2$)$ Un sistema se define por la ecuación de diferencias: $y[n] = 2x[n] - x[n-1]$.
#
# a) Hallar la respuesta al impulso $h[n]$ del sistema (reemplazando $x[n]$ por $\delta[n]$).
#
# b) Graficar y expresar el conjunto por extension $h[n]$.
#
# c) Si la entrada es $x[n] = \{1, 2, 3\}$, calcular la salida $y[n]$ usando la ecuación de diferencias muestra a muestra.

# %% [markdown]
# 3$)$
#
# Dadas las siguientes señales: un pulso rectangular discreto $x_1[n]$ de 10 muestras de duración, y una señal senoidal $x_2[n] = \cos(\frac{\pi}{4} n)$ de duración infinita:
#
# a) Clasifique ambas señales indicando si son de Energía o de Potencia. Justifique conceptualmente.
#
# b) Pregunta teórica: Si en un sistema de adquisición real (como un ADC) tomamos solo 1000 muestras de la señal $x_2[n]$, ¿sigue siendo una señal de potencia o pasa a ser una señal de energía? ¿Por qué?
